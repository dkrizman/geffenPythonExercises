# %%
import numpy as np

# %%
import datetime
myDate = np.datetime64('2021-01-01 22:22:54')
dt = myDate.tolist()

# %%
dt.year
secDelta = np.random.randint(100,101)
diff = np.timedelta64(secDelta,'s')

(myDate+diff).tolist()
# Out:
# datetime.datetime(2021, 1, 1, 22, 24, 34)

# %%
dates = np.arange(np.datetime64('2021-11-13 21:00:00.000'), np.datetime64('2021-11-13 21:00:02.000'))
dates.tolist()
# Out:
# [datetime.datetime(2021, 11, 13, 21, 0),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 1000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 2000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 3000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 4000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 5000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 6000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 7000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 8000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 9000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 10000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 11000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 12000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 13000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 14000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 15000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 16000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 17000),
#  datetime.datetime(2021, 11, 13, 21, 0, 0, 18000),
# ...

# %%
from datetime import datetime as dt
from dateutil.relativedelta import relativedelta as rd

myDate.tolist() + rd(second=55)
# Out:
# datetime.datetime(2021, 1, 1, 22, 22, 55)

# %%
raise Exception ("out of range")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-53-7ba2c6c460df> in <module>
# ----> 1 raise Exception ("out of range")
#
# Exception: out of range
